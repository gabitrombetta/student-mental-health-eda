# %% [markdown]
# # Análise Exploratória de Dados sobre Saúde Mental Estudantil (EDA)
#
# ## Objetivo
#
# Realizar uma análise exploratória dos dados de saúde mental de estudantes,
# identificando padrões, inconsistências e possíveis relações entre variáveis.

# %% [markdown]
# ## Importação das bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carregamento dos dados

# %%
df = pd.read_csv('../data/raw/MentalHealthSurvey.csv')

# %% [markdown]
# ## Visualização inicial

# %%
df.head()
# Out:
#    gender  age university   degree_level      degree_major academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science      2nd year
# 1    Male   20        UET   Postgraduate  Computer Science      3rd year
# 2    Male   20       FAST  Undergraduate  Computer Science      3rd year
# 3    Male   20        UET  Undergraduate  Computer Science      3rd year
# 4  Female   20        UET  Undergraduate  Computer Science      3rd year
#
#       cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.0-3.5         Off-Campus                    No         No Sports  ...
# 1  3.0-3.5         Off-Campus                    No         1-3 times  ...
# 2  2.5-3.0         Off-Campus                    No         1-3 times  ...
# 3  2.5-3.0          On-Campus                    No         No Sports  ...
# 4  3.0-3.5         Off-Campus                   Yes         No Sports  ...
#
#   study_satisfaction  academic_workload   academic_pressure  \
# ...

# %%
df.sample(5)
# Out:
#     gender  age university   degree_level      degree_major academic_year  \
# 70    Male   22        UET  Undergraduate  Computer Science      3rd year
# 0     Male   20         PU  Undergraduate      Data Science      2nd year
# 40  Female   19         PU  Undergraduate      Data Science      2nd year
# 71    Male   20        UET  Undergraduate  Computer Science      3rd year
# 55    Male   21         PU  Undergraduate      Data Science      2nd year
#
#        cgpa residential_status campus_discrimination sports_engagement  ...  \
# 70  2.5-3.0         Off-Campus                    No         No Sports  ...
# 0   3.0-3.5         Off-Campus                    No         No Sports  ...
# 40  2.5-3.0         Off-Campus                    No         1-3 times  ...
# 71  3.0-3.5         Off-Campus                    No          7+ times  ...
# 55  2.5-3.0          On-Campus                   Yes         4-6 times  ...
#
#    study_satisfaction  academic_workload   academic_pressure  \
# ...

# %% [markdown]
# ## Exploração inicial

# %%
print(f'Linhas: {df.shape[0]}')
print(f'Colunas: {df.shape[1]}')
# Out:
# Linhas: 87
# Colunas: 21

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    87 non-null     str
#  1   age                       87 non-null     int64
#  2   university                87 non-null     str
#  3   degree_level              87 non-null     str
#  4   degree_major              87 non-null     str
#  5   academic_year             87 non-null     str
#  6   cgpa                      87 non-null     str
#  7   residential_status        87 non-null     str
#  8   campus_discrimination     87 non-null     str
#  9   sports_engagement         87 non-null     str
#  10  average_sleep             87 non-null     str
#  11  study_satisfaction        87 non-null     int64
#  12  academic_workload         87 non-null     int64
#  13  academic_pressure         87 non-null     int64
# ...

# %%
df.describe(include='all')
# Out:
#        gender        age university   degree_level  degree_major  \
# count      87  87.000000         87             87            87
# unique      2        NaN          9              2             4
# top      Male        NaN         PU  Undergraduate  Data Science
# freq       63        NaN         56             85            41
# mean      NaN  19.942529        NaN            NaN           NaN
# std       NaN   1.623636        NaN            NaN           NaN
# min       NaN  17.000000        NaN            NaN           NaN
# 25%       NaN  19.000000        NaN            NaN           NaN
# 50%       NaN  20.000000        NaN            NaN           NaN
# 75%       NaN  21.000000        NaN            NaN           NaN
# max       NaN  26.000000        NaN            NaN           NaN
#
#        academic_year     cgpa residential_status campus_discrimination  \
# count             87       87                 87                    87
# ...

# %% [markdown]
# ## Qualidade dos dados

# %% [markdown]
# ### Valores nulos

# %%
df.isnull().sum()
# Out:
# gender                      0
# age                         0
# university                  0
# degree_level                0
# degree_major                0
# academic_year               0
# cgpa                        0
# residential_status          0
# campus_discrimination       0
# sports_engagement           0
# average_sleep               0
# study_satisfaction          0
# academic_workload           0
# academic_pressure           0
# financial_concerns          0
# social_relationships        0
# depression                  0
# anxiety                     0
# isolation                   0
# future_insecurity           0
# stress_relief_activities    0
# dtype: int64

# %% [markdown]
# ### Linhas duplicadas

# %%
print(f'Número de linhas duplicadas: {df.duplicated().sum()}')
# Out:
# Número de linhas duplicadas: 0

# %% [markdown]
#  ## Processamento e limpeza dos dados

# %%
from src.preprocessing import process_data

# %%
df = process_data(df)

# %% [markdown]
# ## Verificação pós-processamento

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    87 non-null     str
#  1   age                       87 non-null     int64
#  2   university                87 non-null     str
#  3   degree_level              87 non-null     str
#  4   degree_major              87 non-null     str
#  5   academic_year             87 non-null     int64
#  6   cgpa                      87 non-null     float64
#  7   residential_status        87 non-null     str
#  8   campus_discrimination     87 non-null     str
#  9   sports_engagement         87 non-null     str
#  10  average_sleep             87 non-null     float64
#  11  study_satisfaction        87 non-null     int64
#  12  academic_workload         87 non-null     int64
#  13  academic_pressure         87 non-null     int64
# ...

# %%
df.head()
# Out:
#    gender  age university   degree_level      degree_major  academic_year  \
# 0    Male   20         PU  Undergraduate      Data Science              2
# 1    Male   20        UET   Postgraduate  Computer Science              3
# 2    Male   20       FAST  Undergraduate  Computer Science              3
# 3    Male   20        UET  Undergraduate  Computer Science              3
# 4  Female   20        UET  Undergraduate  Computer Science              3
#
#    cgpa residential_status campus_discrimination sports_engagement  ...  \
# 0  3.25         Off-Campus                    No         No Sports  ...
# 1  3.25         Off-Campus                    No         1-3 times  ...
# 2  2.75         Off-Campus                    No         1-3 times  ...
# 3  2.75          On-Campus                    No         No Sports  ...
# 4  3.25         Off-Campus                   Yes         No Sports  ...
#
#    study_satisfaction  academic_workload  academic_pressure  \
# ...

# %%
df.describe(include='all')
# Out:
#        gender        age university   degree_level  degree_major  \
# count      87  87.000000         87             87            87
# unique      2        NaN          9              2             4
# top      Male        NaN         PU  Undergraduate  Data Science
# freq       63        NaN         56             85            41
# mean      NaN  19.942529        NaN            NaN           NaN
# std       NaN   1.623636        NaN            NaN           NaN
# min       NaN  17.000000        NaN            NaN           NaN
# 25%       NaN  19.000000        NaN            NaN           NaN
# 50%       NaN  20.000000        NaN            NaN           NaN
# 75%       NaN  21.000000        NaN            NaN           NaN
# max       NaN  26.000000        NaN            NaN           NaN
#
#         academic_year       cgpa residential_status campus_discrimination  \
# count       87.000000  87.000000                 87                    87
# ...
